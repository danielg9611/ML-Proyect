# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw/dataset_KS.csv', index_col='ID')

# %%
df['deadline'] = pd.to_datetime(df['deadline'])
df['launched'] = pd.to_datetime(df['launched'])
df = df.sort_values(by='deadline')
df
# Out:
#                                                          name      category  \
# ID
# 1703704063                                drawing for dollars  Illustration
# 2089078683                            New York Makes a Book!!    Journalism
# 813230527   Sponsor Dereck Blackburn (Lostwars) Artist in ...          Rock
# 1147015301  "All We Had" Gets Into Cannes -- $10 or More G...   Documentary
# 199916122                                       Mr. Squiggles  Illustration
# ...                                                       ...           ...
# 1365286494                                From the Wilderness         Drama
# 55596200                           Plateforme de statistiques          Apps
# 1916988520                          Back in Black Hills Movie         Drama
# 22387366                                         Nerd Collect          Apps
# 1036415983                                      Aikyam : Onnu         Music
#
# ...

# %%
df['state'].value_counts()
# Out:
# state
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: count, dtype: int64
